# %% [markdown]
# <a align="center" href="https://ultralytics.com/hub" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/hub/) | [한국어](https://docs.ultralytics.com/ko/hub/) | [日本語](https://docs.ultralytics.com/ja/hub/) | [Русский](https://docs.ultralytics.com/ru/hub/) | [Deutsch](https://docs.ultralytics.com/de/hub/) | [Français](https://docs.ultralytics.com/fr/hub/) | [Español](https://docs.ultralytics.com/es/hub/) | [Português](https://docs.ultralytics.com/pt/hub/) | [Türkçe](https://docs.ultralytics.com/tr/hub/) | [Tiếng Việt](https://docs.ultralytics.com/vi/hub/) | [العربية](https://docs.ultralytics.com/ar/hub/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/hub/actions/workflows/ci.yml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/main/hub.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train Ultralytics [YOLO](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub

checks()  # Verify system setup for Ultralytics training
# Out:
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 39.1/235.7 GB disk)

# %%
# %cd /content/drive/MyDrive/Underwater_YOLOv11s_Latest
# Out:
# /content/drive/MyDrive/Underwater_YOLOv11s_Latest

# %% [markdown]
# # Start
#
# ⚡ Login with your API key, load your YOLO 🚀 model, and start training in 3 lines of code!

# %%
hub.login('835ac93f3c560a3ac28359ae45aa84e1335290b2ec')

model = YOLO('https://hub.ultralytics.com/models/XHEdREv35KDMoIGOgR1x')
results = model.train()
# Out:
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/XHEdREv35KDMoIGOgR1x 🚀
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=None, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=https://app.roboflow.com/ds/8EciWGex7y?key=wKE9C0YdkQ, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://app.roboflow.com/ds/8EciWGex7y to '8EciWGex7y': 100% ━━━━━━━━━━━━ 473.0MB 164.9MB/s 2.9s
# Unzipping 8EciWGex7y to /content/datasets/8EciWGex7y...: 100% ━━━━━━━━━━━━ 24790/24790 7.1Kfiles/s 3.5s
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 12.7MB/s 0.1s
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/Umm85U1ZJTQOzUpksRgX 🚀
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,566 parameters, 9,428,550 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 56.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1190.3±501.3 MB/s, size: 39.5 KB)
# train: Scanning /content/datasets/8EciWGex7y/train/labels... 10833 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10833/10833 1.5Kit/s 7.0s
# train: New cache created: /content/datasets/8EciWGex7y/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA A100-SXM4-40GB) 39.56G total, 0.14G reserved, 0.11G allocated, 39.31G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      9428566       21.55         0.847         86.29          6661        (1, 3, 640, 640)                    list
#      9428566        43.1         1.191         31.63          6241        (2, 3, 640, 640)                    list
#      9428566        86.2         1.741         35.41          8087        (4, 3, 640, 640)                    list
#      9428566       172.4         2.810         37.41          8718        (8, 3, 640, 640)                    list
#      9428566       344.8         4.909          40.2          8214       (16, 3, 640, 640)                    list
#      9428566       689.6         9.083         46.68          7709       (32, 3, 640, 640)                    list
#      9428566        1379        17.253         91.79          7117       (64, 3, 640, 640)                    list
# AutoBatch: Using batch-size 89 for CUDA:0 24.05G/39.56G (61%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1022.4±448.7 MB/s, size: 32.8 KB)
# train: Scanning /content/datasets/8EciWGex7y/train/labels.cache... 10833 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10833/10833 17.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 471.3±235.2 MB/s, size: 34.4 KB)
# val: Scanning /content/datasets/8EciWGex7y/valid/labels... 1039 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1039/1039 1.4Kit/s 0.8s
# val: New cache created: /content/datasets/8EciWGex7y/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0006953125), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      20.5G      1.246      2.127      1.502        150        640: 100% ━━━━━━━━━━━━ 122/122 2.1it/s 58.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 10.5s
#                    all       1039       1119      0.697      0.662      0.725      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      20.5G      1.146      1.064      1.395        156        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.5s
#                    all       1039       1119      0.459      0.568      0.411      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      20.5G      1.207      1.126      1.429        219        640: 35% ━━━━──────── 43/122 2.9it/s 15.4s<27.5s
# 2025-09-09 12:08:07,676 - hub_sdk.helpers.logger - ERROR - Internal server error.
# ERROR:hub_sdk.helpers.logger:Internal server error.
# 2025-09-09 12:08:07,678 - hub_sdk.helpers.logger - ERROR - Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# ERROR:hub_sdk.helpers.logger:Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# Exception in thread Thread-4 (_start_heartbeats):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 178, in _start_heartbeats
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 166, in _start_heartbeats
#     res = self.post(endpoint, json=payload).json()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'json'
#       3/100      20.5G      1.232      1.165      1.449        183        640: 60% ━━━━━━━───── 73/122 2.9it/s 26.0s<17.1s
# 2025-09-09 12:08:18,230 - hub_sdk.helpers.logger - ERROR - Internal server error.
# ERROR:hub_sdk.helpers.logger:Internal server error.
# 2025-09-09 12:08:18,232 - hub_sdk.helpers.logger - ERROR - Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# ERROR:hub_sdk.helpers.logger:Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# Exception in thread Thread-5 (_start_heartbeats):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 178, in _start_heartbeats
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 166, in _start_heartbeats
#     res = self.post(endpoint, json=payload).json()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'json'
#       3/100      20.5G      1.272      1.209       1.48        159        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.5s
#                    all       1039       1119      0.344      0.395      0.276       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      20.5G      1.401      1.371      1.565        151        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.4s
#                    all       1039       1119      0.628      0.266      0.222      0.108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      20.5G      1.333      1.258      1.513        146        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.4s
#                    all       1039       1119      0.523      0.247      0.278      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      20.5G      1.284      1.172      1.471        136        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.757      0.708      0.757       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      20.5G      1.247      1.106      1.443        143        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.684       0.62      0.673      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      20.5G      1.207      1.059      1.416        157        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.777      0.714      0.771       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      20.5G      1.185      1.012      1.396        136        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.4s
#                    all       1039       1119      0.806      0.708      0.782       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      20.5G      1.147     0.9668      1.375        143        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.864      0.815      0.881      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      20.5G      1.142     0.9371      1.365        149        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119       0.84      0.793       0.86      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      20.5G      1.121     0.9052      1.352        130        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.5s
#                    all       1039       1119      0.845      0.849      0.895      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      20.5G      1.106     0.8833      1.341        136        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.875      0.812      0.878      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      20.5G      1.092     0.8614      1.329        152        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.842      0.809      0.868      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      20.5G      1.076     0.8478      1.322        143        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.837      0.794      0.835      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      20.5G      1.055     0.8262      1.304        147        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.847      0.861      0.908      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      20.5G       1.05     0.8243      1.298        154        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.802       0.84       0.88      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      20.5G      1.033     0.7987       1.29        155        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.887      0.834      0.886       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      20.5G      1.027     0.7683       1.28        149        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.885      0.866      0.905      0.652
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/XHEdREv35KDMoIGOgR1x
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      20.5G      1.009     0.7621      1.274        139        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 43.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.916       0.85      0.906      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      20.5G     0.9939     0.7548      1.265        161        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.889      0.857      0.898      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      20.5G     0.9893     0.7473      1.258        129        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.888      0.869      0.917      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      20.5G     0.9787     0.7283       1.25        129        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.867      0.851      0.892      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      20.5G     0.9776     0.7152      1.249        127        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.886      0.847      0.905       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      20.5G     0.9648     0.7117       1.24        162        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.905      0.867      0.912      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      20.5G     0.9553     0.7038      1.234        167        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.4s
#                    all       1039       1119      0.885      0.873      0.884      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      20.5G     0.9486      0.688      1.229        158        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.903      0.873      0.917      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      20.5G     0.9382     0.6882       1.22        130        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 43.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.895      0.873      0.922       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      20.6G     0.9329     0.6773      1.218        146        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.903      0.873      0.904      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      20.5G     0.9222     0.6598      1.215        159        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.895      0.883      0.919      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      20.5G     0.9201     0.6556      1.208        159        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.905      0.883      0.915      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      20.5G     0.9078     0.6376      1.202        148        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.891      0.872      0.903      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      20.5G     0.9023     0.6313      1.203        146        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.922      0.872      0.917       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      20.6G     0.8974     0.6348        1.2        157        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.922      0.874       0.92      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      20.5G     0.8873     0.6256      1.192        153        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.901       0.89      0.918       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      20.5G     0.8799     0.6205      1.186        145        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.918      0.881      0.929      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      20.5G     0.8727     0.6088       1.18        156        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.905      0.889      0.926      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      20.6G     0.8662     0.6055      1.176        146        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.903      0.896       0.91      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      20.6G     0.8627     0.5982      1.174        137        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.899      0.877      0.903       0.68
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/XHEdREv35KDMoIGOgR1x
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      20.5G     0.8473     0.5844      1.168        146        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.917      0.881      0.915      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      20.5G      0.844     0.5874      1.162        148        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.918      0.882       0.93      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      20.5G     0.8378     0.5806      1.163        136        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119       0.91      0.889      0.932      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      20.5G     0.8345     0.5736      1.158        158        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.911      0.901      0.924      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      20.5G     0.8345     0.5766      1.155        161        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.914      0.885      0.911      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      20.5G     0.8173     0.5595      1.148        158        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.912      0.904      0.928      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      20.5G     0.8192       0.56      1.147        158        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119       0.91      0.883      0.917      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      20.5G     0.8078     0.5601      1.145        126        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.925      0.888      0.928      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      20.5G     0.7968     0.5426      1.134        154        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.918      0.895      0.927      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      20.5G     0.7865     0.5399      1.131        142        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.927      0.901      0.933      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      20.5G     0.7819     0.5315      1.129        144        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s
#                    all       1039       1119      0.915      0.883      0.916      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      20.5G     0.7844     0.5265       1.13        142        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.906        0.9       0.93      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      20.6G     0.7737     0.5228      1.124        159        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.926      0.896      0.927      0.715
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      20.5G     0.7703     0.5181      1.124        140        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.897      0.912      0.927       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      20.5G     0.7596     0.5084      1.113        137        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.917      0.897      0.936      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      20.5G       0.76     0.5116      1.111        134        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.925      0.899      0.929      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      20.5G     0.7469     0.5011      1.107        147        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.908      0.905      0.932      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      20.5G     0.7491     0.5054       1.11        133        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.909      0.901      0.925      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      20.5G     0.7425     0.4951      1.102        145        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.915      0.898      0.937      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      20.5G      0.733      0.489      1.101        142        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.922      0.903      0.936      0.728
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/XHEdREv35KDMoIGOgR1x
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      20.5G     0.7265      0.485      1.099        162        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.905      0.887       0.93      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      20.5G     0.7232       0.48      1.096        157        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119       0.92      0.902      0.934      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      20.5G     0.7145     0.4801      1.089        150        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.912      0.895      0.929      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      20.5G     0.7058     0.4695      1.085        159        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.922      0.893      0.939       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      20.5G      0.699     0.4653      1.081        131        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119       0.93      0.894      0.934      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      20.5G     0.6923     0.4605      1.078        128        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.934      0.895      0.941      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      20.5G     0.6923     0.4584      1.076        162        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.918      0.902      0.934      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      20.5G     0.6851      0.445      1.074        155        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.917      0.893      0.931      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      20.5G     0.6784     0.4471      1.068        124        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.913      0.892      0.929      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      20.5G     0.6732     0.4409      1.067        132        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.2s
#                    all       1039       1119      0.935      0.891      0.931      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      20.5G     0.6632     0.4354      1.064        136        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.926      0.893      0.926      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      20.5G     0.6623     0.4342      1.064        145        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.922      0.905      0.933      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      20.5G      0.655     0.4268      1.061        148        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.929      0.889      0.936      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      20.5G     0.6535     0.4231      1.056        138        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.926      0.889      0.932      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      20.5G     0.6446     0.4206      1.051        138        640: 100% ━━━━━━━━━━━━ 122/122 2.9it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.925      0.893      0.932      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      20.5G     0.6472     0.4202      1.054        142        640: 100% ━━━━━━━━━━━━ 122/122 2.8it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all       1039       1119      0.916      0.898       0.93      0.724
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 65, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 75 epochs completed in 0.982 hours.
# Optimizer stripped from /content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3/weights/last.pt, 19.2MB
# Optimizer stripped from /content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3/weights/best.pt, 19.2MB
#
# Validating /content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2it/s 4.9s
#                    all       1039       1119      0.934      0.894      0.941      0.737
#               drowning        635        644      0.965      0.888      0.959      0.772
#                 normal        409        475      0.903      0.901      0.923      0.702
# Speed: 0.1ms preprocess, 0.8ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/drive/MyDrive/Underwater_YOLOv11s_Latest/runs/detect/train3
# Ultralytics HUB: Syncing final model...
# : 100% ━━━━━━━━━━━━ 18.3MB 13.6MB/s 1.3s
# Ultralytics HUB: Done ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/XHEdREv35KDMoIGOgR1x 🚀
