# %% [markdown]
# <a align="center" href="https://ultralytics.com/hub" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/hub/) | [한국어](https://docs.ultralytics.com/ko/hub/) | [日本語](https://docs.ultralytics.com/ja/hub/) | [Русский](https://docs.ultralytics.com/ru/hub/) | [Deutsch](https://docs.ultralytics.com/de/hub/) | [Français](https://docs.ultralytics.com/fr/hub/) | [Español](https://docs.ultralytics.com/es/hub/) | [Português](https://docs.ultralytics.com/pt/hub/) | [Türkçe](https://docs.ultralytics.com/tr/hub/) | [Tiếng Việt](https://docs.ultralytics.com/vi/hub/) | [العربية](https://docs.ultralytics.com/ar/hub/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/hub/actions/workflows/ci.yml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/main/hub.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train Ultralytics [YOLO](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub

checks()  # Verify system setup for Ultralytics training
# Out:
# Ultralytics 8.3.191 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 39.0/235.7 GB disk)

# %%
# %cd /content/drive/MyDrive/Abovewater_YOLOv11s_100_epochs
# Out:
# /content/drive/MyDrive/Abovewater_YOLOv11s_100_epochs

# %% [markdown]
# # Start
#
# ⚡ Login with your API key, load your YOLO 🚀 model, and start training in 3 lines of code!

# %%
hub.login('835ac93f3c560a3ac28359ae45aa84e1335290b2ec')

model = YOLO('https://hub.ultralytics.com/models/Gp50TvnpHhUUqseBGCnn')
results = model.train()
# Out:
# requirements: Ultralytics requirement ['hub-sdk>=0.0.12'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/Gp50TvnpHhUUqseBGCnn 🚀
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4/18.4MB 124.1MB/s 0.1s
# Ultralytics 8.3.191 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=None, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=https://app.roboflow.com/ds/wlL9kRNk2a?key=TKVwHV14bD, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://app.roboflow.com/ds/wlL9kRNk2a to 'wlL9kRNk2a': 100% ━━━━━━━━━━━━ 453.8/453.8MB 211.3MB/s 2.1s
# Unzipping wlL9kRNk2a to /content/datasets/wlL9kRNk2a...: 100% ━━━━━━━━━━━━ 19148/19148 6392.5files/s 3.0s
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1/755.1KB 13.0MB/s 0.1s
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/41w8MQFvjiZqimr7NY4K 🚀
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,566 parameters, 9,428,550 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 57.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1375.0±586.7 MB/s, size: 46.6 KB)
# train: Scanning /content/datasets/wlL9kRNk2a/train/labels... 8274 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8274/8274 1507.8it/s 5.5s
# train: /content/datasets/wlL9kRNk2a/train/images/Swimming_form_critique_mp4-0019_jpg.rf.21a728fda4ae366dcc5cadf610942773.jpg: 1 duplicate labels removed
# train: /content/datasets/wlL9kRNk2a/train/images/Swimming_form_critique_mp4-0019_jpg.rf.36180498676b121b8030a595b1161730.jpg: 1 duplicate labels removed
# train: /content/datasets/wlL9kRNk2a/train/images/Swimming_form_critique_mp4-0019_jpg.rf.b80c0e178bc8a16f30c173e1997b9108.jpg: 1 duplicate labels removed
# train: New cache created: /content/datasets/wlL9kRNk2a/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA A100-SXM4-40GB) 39.56G total, 0.14G reserved, 0.11G allocated, 39.31G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      9428566       21.55         0.847         77.08          6746        (1, 3, 640, 640)                    list
#      9428566        43.1         1.191         32.62          6398        (2, 3, 640, 640)                    list
#      9428566        86.2         1.741         36.95          8259        (4, 3, 640, 640)                    list
#      9428566       172.4         2.810         37.56          8883        (8, 3, 640, 640)                    list
#      9428566       344.8         4.909         39.08          8399       (16, 3, 640, 640)                    list
#      9428566       689.6         9.081         46.88          7832       (32, 3, 640, 640)                    list
#      9428566        1379        17.253         91.77          7283       (64, 3, 640, 640)                    list
# AutoBatch: Using batch-size 89 for CUDA:0 24.05G/39.56G (61%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1341.2±765.6 MB/s, size: 48.0 KB)
# train: Scanning /content/datasets/wlL9kRNk2a/train/labels.cache... 8274 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8274/8274 11752005.2it/s 0.0s
# train: /content/datasets/wlL9kRNk2a/train/images/Swimming_form_critique_mp4-0019_jpg.rf.21a728fda4ae366dcc5cadf610942773.jpg: 1 duplicate labels removed
# train: /content/datasets/wlL9kRNk2a/train/images/Swimming_form_critique_mp4-0019_jpg.rf.36180498676b121b8030a595b1161730.jpg: 1 duplicate labels removed
# train: /content/datasets/wlL9kRNk2a/train/images/Swimming_form_critique_mp4-0019_jpg.rf.b80c0e178bc8a16f30c173e1997b9108.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 530.9±223.7 MB/s, size: 54.7 KB)
# val: Scanning /content/datasets/wlL9kRNk2a/valid/labels... 756 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 756/756 1356.2it/s 0.6s
# val: New cache created: /content/datasets/wlL9kRNk2a/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0006953125), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      20.6G      1.705      3.055      1.811        205        640: 100% ━━━━━━━━━━━━ 93/93 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.50it/s 10.1s
#                    all        756        900      0.121      0.159     0.0817     0.0284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      20.5G       1.75      1.913      1.848        191        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900     0.0965     0.0773      0.028    0.00954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      20.6G      1.762      1.914      1.843        186        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        756        900      0.186      0.203      0.131     0.0501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      20.5G      1.729      1.828      1.813        168        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.484      0.464      0.434      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      20.6G      1.666      1.695      1.757        193        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900      0.488      0.469       0.46       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      20.5G      1.593      1.578      1.705        176        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900      0.635       0.56      0.622      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      20.5G      1.575      1.512      1.689        177        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900      0.697      0.633      0.692      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      20.5G      1.525      1.452      1.659        203        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.6s
#                    all        756        900      0.483      0.464      0.428      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      20.6G      1.498      1.387      1.628        194        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900      0.632      0.641      0.659        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      20.5G      1.485      1.357      1.622        174        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.6s
#                    all        756        900      0.721       0.69      0.749      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      20.6G      1.454      1.309      1.602        178        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900      0.768      0.629      0.723       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      20.5G      1.426       1.26      1.573        205        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.722       0.74       0.79      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      20.5G      1.415      1.241      1.564        210        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.783      0.736      0.812      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      20.6G      1.407       1.23      1.563        187        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900      0.745      0.695      0.765      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      20.5G      1.378       1.18      1.538        204        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.771      0.723      0.794      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      20.6G      1.369      1.154      1.527        189        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        756        900       0.78      0.754      0.816      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      20.5G      1.345      1.102      1.508        206        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.807      0.714      0.809      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      20.5G      1.331      1.098      1.497        197        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.806      0.731      0.819      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      20.6G      1.305       1.08      1.483        191        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.793      0.776      0.831      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      20.6G      1.308      1.059      1.482        174        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.783      0.783      0.831      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      20.5G      1.295      1.021      1.468        204        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.818      0.764      0.834      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      20.6G      1.282      1.027      1.456        190        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.6s
#                    all        756        900      0.818      0.754      0.831      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      20.5G      1.274     0.9931      1.448        197        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.6s
#                    all        756        900      0.808      0.773       0.83      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      20.5G      1.246     0.9786      1.432        208        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.802      0.735      0.818       0.47
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/Gp50TvnpHhUUqseBGCnn
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      20.6G      1.254      0.957      1.429        193        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.822      0.791      0.857       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      20.6G       1.23      0.926      1.415        192        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.818      0.777      0.858       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      20.6G       1.22     0.9329      1.408        187        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.841       0.79      0.864      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      20.6G      1.213     0.9033        1.4        179        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.845      0.794      0.857       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      20.5G      1.195     0.8988      1.393        206        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.826      0.819      0.865      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      20.6G      1.201     0.8821       1.39        210        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.823      0.829      0.875      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      20.6G      1.196     0.8792      1.392        204        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.859      0.815      0.881      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      20.6G      1.165     0.8549      1.371        210        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.841      0.823      0.881      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      20.5G      1.159     0.8347      1.362        192        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.843       0.79      0.858      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      20.5G      1.164     0.8413      1.366        194        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.841      0.792      0.864      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      20.6G      1.138     0.8063      1.348        182        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.865       0.79      0.868      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      20.6G      1.138     0.8201      1.343        196        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.857      0.809      0.874       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      20.6G      1.116     0.7926      1.331        177        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.838       0.83      0.875      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      20.7G      1.122     0.7979      1.337        215        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.854      0.823      0.883      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      20.6G      1.111     0.7807      1.327        184        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.832      0.827      0.865      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      20.6G      1.117     0.7842      1.325        222        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.857        0.8      0.876      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      20.5G      1.085     0.7695      1.308        207        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.853      0.803       0.87      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      20.6G      1.082      0.752        1.3        168        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.851      0.824      0.875      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      20.6G       1.07      0.744      1.298        180        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.882      0.807      0.878      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      20.5G      1.065     0.7297      1.291        198        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.4s
#                    all        756        900      0.846      0.804      0.874      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      20.5G      1.056     0.7234       1.29        203        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.857      0.803      0.883      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      20.6G      1.049     0.7214      1.288        173        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.861      0.821      0.883      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      20.6G      1.048     0.7139      1.288        192        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.842      0.827      0.882      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      20.6G      1.031     0.7052      1.275        219        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.869      0.809      0.873      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      20.5G      1.024     0.6922      1.262        215        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.857      0.824      0.877      0.552
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/Gp50TvnpHhUUqseBGCnn
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      20.6G      1.018      0.688       1.26        183        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.843       0.81      0.872      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      20.6G       1.02     0.6913      1.263        198        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.871      0.804      0.878      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      20.6G      1.007     0.6656      1.246        176        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.847       0.83      0.874      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      20.5G      0.983     0.6673      1.243        206        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.4s
#                    all        756        900      0.859      0.815      0.876      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      20.6G     0.9882     0.6688      1.242        188        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.859      0.798      0.872       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      20.5G     0.9816     0.6573       1.24        205        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.4s
#                    all        756        900       0.86      0.836      0.882      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      20.6G      0.975     0.6454      1.233        196        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.866      0.799      0.875      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      20.5G     0.9593      0.626       1.22        183        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.848      0.837      0.879      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      20.5G     0.9528     0.6352       1.22        179        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.861      0.826      0.876      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      20.6G     0.9445     0.6378      1.217        185        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.866      0.818      0.877      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      20.6G     0.9516     0.6296      1.216        215        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.4s
#                    all        756        900      0.857      0.831      0.882      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      20.5G     0.9318      0.613       1.21        188        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.872      0.829      0.886      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      20.6G     0.9269     0.6113      1.202        195        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.4s
#                    all        756        900      0.861      0.836       0.88      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      20.5G     0.9144     0.5971      1.195        222        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900       0.87      0.813      0.868      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      20.6G     0.9108     0.5942      1.194        185        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.845      0.838      0.871      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      20.5G     0.9015     0.5941      1.188        180        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.857      0.831      0.873      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      20.6G     0.8973     0.5887      1.187        183        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.871      0.819      0.882      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      20.5G     0.8916     0.5749      1.182        183        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.866      0.819      0.872      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      20.6G     0.8887     0.5717      1.175        178        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.864       0.82      0.879      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      20.6G     0.8689     0.5581      1.167        174        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.867      0.812      0.877      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      20.6G      0.867     0.5604      1.161        198        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.4s
#                    all        756        900      0.854      0.833      0.873      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      20.6G     0.8689     0.5614      1.168        177        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.868      0.812      0.879       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      20.6G     0.8581     0.5515      1.162        198        640: 100% ━━━━━━━━━━━━ 93/93 2.8it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0it/s 2.5s
#                    all        756        900      0.863      0.811      0.874      0.556
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 62, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 72 epochs completed in 0.739 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 19.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 19.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.191 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3it/s 3.7s
#                    all        756        900       0.86      0.835       0.88      0.571
#               drowning        428        434      0.852      0.836      0.882      0.543
#                 normal        372        466      0.869      0.833      0.878      0.599
# Speed: 0.1ms preprocess, 0.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train
# Ultralytics HUB: Syncing final model...
# : 100% ━━━━━━━━━━━━ 18.3/18.3MB 13.4MB/s 1.4s
# Ultralytics HUB: Done ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/Gp50TvnpHhUUqseBGCnn 🚀
