# %% [markdown]
# <a align="center" href="https://ultralytics.com/hub" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/hub/) | [한국어](https://docs.ultralytics.com/ko/hub/) | [日本語](https://docs.ultralytics.com/ja/hub/) | [Русский](https://docs.ultralytics.com/ru/hub/) | [Deutsch](https://docs.ultralytics.com/de/hub/) | [Français](https://docs.ultralytics.com/fr/hub/) | [Español](https://docs.ultralytics.com/es/hub/) | [Português](https://docs.ultralytics.com/pt/hub/) | [Türkçe](https://docs.ultralytics.com/tr/hub/) | [Tiếng Việt](https://docs.ultralytics.com/vi/hub/) | [العربية](https://docs.ultralytics.com/ar/hub/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/hub/actions/workflows/ci.yml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/main/hub.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train Ultralytics [YOLO](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub

checks()  # Verify system setup for Ultralytics training
# Out:
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 39.1/235.7 GB disk)

# %%
# %cd /content/drive/MyDrive/Abovewater_YOLOv11s_Latest
# Out:
# /content/drive/MyDrive/Abovewater_YOLOv11s_Latest

# %% [markdown]
# # Start
#
# ⚡ Login with your API key, load your YOLO 🚀 model, and start training in 3 lines of code!

# %%
hub.login('835ac93f3c560a3ac28359ae45aa84e1335290b2ec')

model = YOLO('https://hub.ultralytics.com/models/b0LzZ9Wq94TNG3BJdoF9')
results = model.train()
# Out:
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/b0LzZ9Wq94TNG3BJdoF9 🚀
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=None, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=https://app.roboflow.com/ds/fYWrJS6nPX?key=bMVJf06koQ, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://app.roboflow.com/ds/fYWrJS6nPX to 'fYWrJS6nPX': 100% ━━━━━━━━━━━━ 501.4MB 211.3MB/s 2.4s
# Unzipping fYWrJS6nPX to /content/datasets/fYWrJS6nPX...: 100% ━━━━━━━━━━━━ 20410/20410 6.3Kfiles/s 3.2s
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 13.9MB/s 0.1s
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/3zSaOivWt03MilqRiFFo 🚀
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,566 parameters, 9,428,550 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 4.8MB/s 1.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1599.3±627.5 MB/s, size: 61.5 KB)
# train: Scanning /content/datasets/fYWrJS6nPX/train/labels... 8826 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8826/8826 1.5Kit/s 5.9s
# train: /content/datasets/fYWrJS6nPX/train/images/Swimming_form_critique_mp4-0019_jpg.rf.1edeca4d34ce9dc91dcf6797a54d8ecb.jpg: 1 duplicate labels removed
# train: /content/datasets/fYWrJS6nPX/train/images/Swimming_form_critique_mp4-0019_jpg.rf.21a728fda4ae366dcc5cadf610942773.jpg: 1 duplicate labels removed
# train: /content/datasets/fYWrJS6nPX/train/images/Swimming_form_critique_mp4-0019_jpg.rf.e453c67d72e35452c8c26068af667834.jpg: 1 duplicate labels removed
# train: New cache created: /content/datasets/fYWrJS6nPX/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA A100-SXM4-40GB) 39.56G total, 0.14G reserved, 0.11G allocated, 39.31G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      9428566       21.55         0.847         74.57          6603        (1, 3, 640, 640)                    list
#      9428566        43.1         1.191         32.24          6328        (2, 3, 640, 640)                    list
#      9428566        86.2         1.741         33.94          8094        (4, 3, 640, 640)                    list
#      9428566       172.4         2.810         36.02          8661        (8, 3, 640, 640)                    list
#      9428566       344.8         4.909         38.54          8206       (16, 3, 640, 640)                    list
#      9428566       689.6         9.083         46.57          7692       (32, 3, 640, 640)                    list
#      9428566        1379        17.253         91.62          7096       (64, 3, 640, 640)                    list
# AutoBatch: Using batch-size 89 for CUDA:0 24.05G/39.56G (61%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1325.3±519.0 MB/s, size: 36.5 KB)
# train: Scanning /content/datasets/fYWrJS6nPX/train/labels.cache... 8826 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8826/8826 13.3Mit/s 0.0s
# train: /content/datasets/fYWrJS6nPX/train/images/Swimming_form_critique_mp4-0019_jpg.rf.1edeca4d34ce9dc91dcf6797a54d8ecb.jpg: 1 duplicate labels removed
# train: /content/datasets/fYWrJS6nPX/train/images/Swimming_form_critique_mp4-0019_jpg.rf.21a728fda4ae366dcc5cadf610942773.jpg: 1 duplicate labels removed
# train: /content/datasets/fYWrJS6nPX/train/images/Swimming_form_critique_mp4-0019_jpg.rf.e453c67d72e35452c8c26068af667834.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1017.3±801.2 MB/s, size: 61.8 KB)
# val: Scanning /content/datasets/fYWrJS6nPX/valid/labels... 809 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 809/809 1.2Kit/s 0.7s
# val: New cache created: /content/datasets/fYWrJS6nPX/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0006953125), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      20.6G      1.587      2.815      1.671         31        640: 100% ━━━━━━━━━━━━ 100/100 1.6it/s 1:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 10.3s
#                    all        809        981      0.354      0.382      0.303      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      20.7G      1.638      1.725      1.689         37        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s
#                    all        809        981      0.681      0.144      0.194     0.0876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      20.6G      1.782      1.833      1.795        197        640: 1% ──────────── 1/100 0.8it/s 0.7s<1:57
# 2025-09-09 10:03:27,702 - hub_sdk.helpers.logger - ERROR - Internal server error.
# ERROR:hub_sdk.helpers.logger:Internal server error.
# 2025-09-09 10:03:27,705 - hub_sdk.helpers.logger - ERROR - Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# ERROR:hub_sdk.helpers.logger:Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# Exception in thread Thread-4 (_start_heartbeats):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 178, in _start_heartbeats
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 166, in _start_heartbeats
#     res = self.post(endpoint, json=payload).json()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'json'
#       3/100      20.6G      1.683      1.748      1.718        186        640: 34% ━━━━──────── 34/100 2.8it/s 12.5s<23.2s
# 2025-09-09 10:03:39,637 - hub_sdk.helpers.logger - ERROR - Internal server error.
# ERROR:hub_sdk.helpers.logger:Internal server error.
# 2025-09-09 10:03:39,639 - hub_sdk.helpers.logger - ERROR - Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# ERROR:hub_sdk.helpers.logger:Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# Exception in thread Thread-5 (_start_heartbeats):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 178, in _start_heartbeats
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 166, in _start_heartbeats
#     res = self.post(endpoint, json=payload).json()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'json'
#       3/100      20.6G      1.678      1.749      1.717        198        640: 74% ━━━━━━━━╸─── 74/100 2.8it/s 26.7s<9.4s
# 2025-09-09 10:03:53,921 - hub_sdk.helpers.logger - ERROR - Internal server error.
# ERROR:hub_sdk.helpers.logger:Internal server error.
# 2025-09-09 10:03:53,922 - hub_sdk.helpers.logger - ERROR - Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# ERROR:hub_sdk.helpers.logger:Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# Exception in thread Thread-6 (_start_heartbeats):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 178, in _start_heartbeats
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/hub_sdk/base/server_clients.py", line 166, in _start_heartbeats
#     res = self.post(endpoint, json=payload).json()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'json'
#       3/100      20.6G      1.672      1.732      1.711         34        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981      0.296      0.424      0.297      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      20.5G      1.619      1.651       1.68         36        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981      0.464      0.459      0.446      0.212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      20.6G      1.542      1.465      1.603         36        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981       0.46      0.468       0.44      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      20.6G      1.496      1.388      1.573         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s
#                    all        809        981      0.628      0.605      0.641      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      20.6G       1.46      1.329      1.546         25        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981      0.726      0.613       0.67      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      20.6G      1.413      1.272      1.517         30        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981      0.703      0.661        0.7      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      20.5G      1.388      1.187      1.489         38        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.676      0.632      0.685      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      20.5G      1.373      1.177      1.482         38        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981      0.706      0.667      0.727      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      20.5G      1.351      1.125      1.457         33        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981      0.701      0.614      0.681       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      20.6G       1.33      1.087      1.448         24        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.741      0.676      0.757      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      20.5G      1.317      1.082       1.44         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.747      0.725      0.775      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      20.6G      1.303      1.044      1.428         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.735      0.755      0.797      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      20.5G       1.28       1.01      1.411         42        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.723      0.728      0.772       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      20.5G      1.261     0.9901      1.396         30        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.782      0.745      0.819      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      20.5G       1.24     0.9535      1.377         39        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.819      0.741      0.834      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      20.6G      1.244     0.9545      1.378         38        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.797      0.748      0.828      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      20.6G       1.21     0.9344      1.362         37        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.799      0.799      0.842      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      20.5G      1.191     0.8962      1.345         20        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.819      0.773      0.852      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      20.5G      1.179     0.8936       1.34         35        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.796      0.798      0.849      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      20.5G      1.166     0.8601       1.33         35        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.824      0.771      0.844      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      20.6G      1.163     0.8675      1.332         24        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981        0.8      0.766      0.832      0.495
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/b0LzZ9Wq94TNG3BJdoF9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      20.6G      1.152     0.8442      1.324         31        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.829      0.792      0.851      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      20.5G      1.136     0.8229      1.304         31        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.842      0.771      0.862      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      20.6G      1.124     0.8063      1.299         36        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.854      0.807      0.864      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      20.6G      1.111     0.8007      1.295         28        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s
#                    all        809        981       0.83      0.805      0.871      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      20.6G      1.104     0.7869      1.287         36        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.827      0.794      0.871      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      20.6G      1.106     0.7866      1.286         31        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981       0.85      0.797      0.869      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      20.5G      1.083     0.7591      1.278         27        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.809      0.836      0.866      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      20.6G      1.069     0.7452      1.267         43        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981       0.84      0.831      0.871      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      20.5G      1.063     0.7426      1.267         24        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.863      0.802      0.877       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      20.6G      1.039     0.7156      1.241         26        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.813      0.817       0.86      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      20.5G      1.045     0.7113      1.244         20        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.842      0.808      0.874      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      20.5G      1.031     0.7036      1.242         36        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.852      0.824      0.872      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      20.6G      1.017     0.6929      1.229         34        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.845      0.838      0.879      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      20.6G      1.015     0.6895      1.226         33        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.848      0.827      0.872      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      20.5G     0.9965     0.6735      1.216         26        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981       0.85      0.832      0.883      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      20.5G     0.9917     0.6683      1.211         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.855      0.832      0.878      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      20.5G     0.9766     0.6557      1.205         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.7s
#                    all        809        981      0.848      0.806      0.881      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      20.5G     0.9695     0.6533      1.198         41        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.851      0.824      0.874      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      20.5G      0.957      0.634      1.194         30        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.862      0.834      0.883       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      20.6G     0.9453     0.6285      1.188         31        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.859      0.816       0.88      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      20.5G     0.9361     0.6184      1.178         28        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.863      0.817      0.884      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      20.6G     0.9319     0.6095      1.173         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.862      0.825      0.884      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      20.5G      0.914     0.6093      1.167         33        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.871      0.823      0.886      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      20.5G      0.912     0.5952      1.163         36        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981       0.83      0.851      0.883      0.549
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/b0LzZ9Wq94TNG3BJdoF9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      20.5G     0.9012      0.599      1.158         35        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.859      0.831       0.89      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      20.6G     0.8975     0.5887      1.155         31        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.873      0.808      0.885      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      20.5G     0.8815     0.5755      1.144         37        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.834      0.824      0.875      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      20.6G     0.8745     0.5734      1.147         41        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.872      0.826      0.885       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      20.6G     0.8729     0.5771      1.145         39        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.873      0.838      0.886      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      20.5G     0.8584     0.5586      1.132         49        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.878      0.811      0.874      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      20.6G     0.8498     0.5594      1.126         34        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.851      0.841      0.875      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      20.6G     0.8368     0.5482      1.121         22        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.853      0.843      0.877      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      20.5G     0.8403     0.5466      1.125         29        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.856      0.826      0.875      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      20.5G     0.8257     0.5357      1.117         37        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981      0.856      0.836      0.884      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      20.5G     0.8214     0.5313      1.112         22        640: 100% ━━━━━━━━━━━━ 100/100 2.8it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.9it/s 2.6s
#                    all        809        981       0.86       0.83      0.883      0.564
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 48, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 58 epochs completed in 0.636 hours.
# Optimizer stripped from /content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4/weights/last.pt, 19.2MB
# Optimizer stripped from /content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4/weights/best.pt, 19.2MB
#
# Validating /content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.1s
#                    all        809        981      0.859      0.831       0.89      0.567
#               drowning        441        447      0.847      0.832      0.889      0.535
#                 normal        421        534       0.87       0.83      0.891      0.599
# Speed: 0.1ms preprocess, 0.8ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/drive/MyDrive/Abovewater_YOLOv11s_Latest/runs/detect/train4
# Ultralytics HUB: Syncing final model...
# : 100% ━━━━━━━━━━━━ 18.3MB 13.8MB/s 1.3s
# Ultralytics HUB: Done ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/b0LzZ9Wq94TNG3BJdoF9 🚀
